# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
import requests
import zipfile
import io

url = "https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip"
response = requests.get(url)

with zipfile.ZipFile(io.BytesIO(response.content)) as z:
    z.extractall()

# %%
import os

files = os.listdir("Data")
info = []
marks =[]
files=sorted(files)
for file in files:
    if 'info' in file:
        info1 = pd.read_csv(os.path.join("Data", file))
        info.append(info1)
    else:
        mark = pd.read_csv(os.path.join("Data", file))
        marks.append(mark)
df1=pd.concat(info)
df2=pd.concat(marks)

# %%
jointed = df2.merge(df1, on = 'index', how='inner')
jointed.head(5)
# Out:
#    index  math score  reading score  writing score  gender race/ethnicity  \
# 0      0          72             72             74  female        group B
# 1      1          69             90             88  female        group C
# 2      2          90             95             93  female        group B
# 3      3          47             57             44    male        group A
# 4      4          76             78             75    male        group C
#
#   parental level of education         lunch test preparation course   group
# 0           bachelor's degree      standard                    none  group1
# 1                some college      standard               completed  group1
# 2             master's degree      standard                    none  group1
# 3          associate's degree  free/reduced                    none  group1
# 4                some college      standard                    none  group1

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
del jointed['index']
jointed.head(10)
# Out:
#    math score  reading score  writing score  gender race/ethnicity  \
# 0          72             72             74  female        group B
# 1          69             90             88  female        group C
# 2          90             95             93  female        group B
# 3          47             57             44    male        group A
# 4          76             78             75    male        group C
# 5          71             83             78  female        group B
# 6          88             95             92  female        group B
# 7          40             43             39    male        group B
# 8          64             64             67    male        group D
# 9          38             60             50  female        group B
#
#   parental level of education         lunch test preparation course   group
# 0           bachelor's degree      standard                    none  group1
# 1                some college      standard               completed  group1
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
jointed.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
jointed.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
jointed.isnull().sum()
# Out:
# math score                     0
# reading score                  0
# writing score                  0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# dtype: int64

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
print(jointed['math score'].mean())
print(jointed['reading score'].mean())
print(jointed['writing score'].mean())
# Out:
# 66.089
# 69.169
# 68.054

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
average_score=jointed.groupby(['test preparation course'])['reading score', 'math score', 'writing score'].mean()
average_score
# Out:
# /var/folders/vw/j2t_ls8d2_n0z8_4yyzcrl640000gn/T/ipykernel_14108/2022020717.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   average_score=jointed.groupby(['test preparation course'])['reading score', 'math score', 'writing score'].mean()
#                          reading score  math score  writing score
# test preparation course
# completed                    73.893855   69.695531      74.418994
# none                         66.534268   64.077882      64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
jointed['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
new_df = jointed.rename(columns = {'parental level of education': 'education',"test preparation course": "test preparation"})
new_df
# Out:
#      math score  reading score  writing score  gender race/ethnicity  \
# 0            72             72             74  female        group B
# 1            69             90             88  female        group C
# 2            90             95             93  female        group B
# 3            47             57             44    male        group A
# 4            76             78             75    male        group C
# ..          ...            ...            ...     ...            ...
# 995          88             99             95  female        group E
# 996          62             55             55    male        group C
# 997          59             71             65  female        group C
# 998          68             78             77  female        group D
# 999          77             86             86  female        group D
#
#               education         lunch test preparation    group
# 0     bachelor's degree      standard             none   group1
# ...

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
new_df[new_df['math score'] >= passmark].shape[0]/new_df.shape[0]
# Out:
# 0.865

# %%
new_df[(new_df['math score'] >= passmark) & (new_df['test preparation'] == 'completed')].shape[0]/new_df[new_df['test preparation']=='completed'].shape[0]
# Out:
# 0.9217877094972067

# %%
new_df[(new_df['math score'] < passmark) & (new_df['test preparation'] == 'none') & (new_df['gender'] == 'female')].shape[0]/new_df[(new_df["test preparation"] == "none") & (new_df["gender"] == "female")].shape[0]
# Out:
# 0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%time
new_df.groupby(['race/ethnicity'])['reading score'].mean()
# Out:
# CPU times: user 2.61 ms, sys: 805 µs, total: 3.42 ms
# Wall time: 2.73 ms
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64

# %%
# %%time
new_df.groupby(['education'])['writing score'].min()
# Out:
# CPU times: user 3.6 ms, sys: 1.74 ms, total: 5.34 ms
# Wall time: 5.92 ms
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%time
average_reading_marks={}
for i in new_df['race/ethnicity'].unique():
    average_reading_mark = new_df[new_df['race/ethnicity'] == i]['reading score'].mean()
    average_reading_marks[i]= average_reading_mark
print(average_reading_marks)
# Out:
# {'group B': 67.35263157894737, 'group C': 69.10344827586206, 'group A': 64.67415730337079, 'group D': 70.03053435114504, 'group E': 73.02857142857142}
# CPU times: user 7.74 ms, sys: 1.04 ms, total: 8.78 ms
# Wall time: 8.08 ms

# %%
# %%time
average_writing_marks={}
for i in new_df['education'].unique():
    average_writing_mark = new_df[new_df['education'] == i]['writing score'].min()
    average_writing_marks[i]= average_writing_mark
print(average_writing_marks)
# Out:
# {"bachelor's degree": 38, 'some college': 19, "master's degree": 46, "associate's degree": 35, 'high school': 15, 'some high school': 10}
# CPU times: user 9.99 ms, sys: 1.8 ms, total: 11.8 ms
# Wall time: 11.6 ms

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
grouped = pd.pivot_table(data=new_df, index=['gender', 'education'])
grouped
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
def mark(score):
    if score < passmark:
        return "F"
    else:
        return "P"

# %%
new_df['Math_PassStatus'] = new_df['math score'].apply(mark)
new_df['Reading_PassStatus'] = new_df['reading score'].apply(mark)
new_df['Writing_PassStatus'] = new_df['writing score'].apply(mark)
new_df
# Out:
#      math score  reading score  writing score  gender race/ethnicity  \
# 0            72             72             74  female        group B
# 1            69             90             88  female        group C
# 2            90             95             93  female        group B
# 3            47             57             44    male        group A
# 4            76             78             75    male        group C
# ..          ...            ...            ...     ...            ...
# 995          88             99             95  female        group E
# 996          62             55             55    male        group C
# 997          59             71             65  female        group C
# 998          68             78             77  female        group D
# 999          77             86             86  female        group D
#
#               education         lunch test preparation    group  \
# 0     bachelor's degree      standard             none   group1
# ...

# %%
new_df['Math_PassStatus'].value_counts()
# Out:
# P    865
# F    135
# Name: Math_PassStatus, dtype: int64

# %%
new_df['Reading_PassStatus'].value_counts()
# Out:
# P    910
# F     90
# Name: Reading_PassStatus, dtype: int64

# %%
new_df['Writing_PassStatus'].value_counts()
# Out:
# P    886
# F    114
# Name: Writing_PassStatus, dtype: int64

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
def result(row):
    if row['Math_PassStatus'] == 'F' or row['Reading_PassStatus'] == "F" or row['Writing_PassStatus'] == 'F':
        return "F"
    else:
        return "P"

new_df['OverAll_PassStatus'] = new_df.apply(result, axis=1)
new_df
# Out:
#      math score  reading score  writing score  gender race/ethnicity  \
# 0            72             72             74  female        group B
# 1            69             90             88  female        group C
# 2            90             95             93  female        group B
# 3            47             57             44    male        group A
# 4            76             78             75    male        group C
# ..          ...            ...            ...     ...            ...
# 995          88             99             95  female        group E
# 996          62             55             55    male        group C
# 997          59             71             65  female        group C
# 998          68             78             77  female        group D
# 999          77             86             86  female        group D
#
#               education         lunch test preparation    group  \
# 0     bachelor's degree      standard             none   group1
# ...

# %%
(new_df['OverAll_PassStatus'] == "P").sum()
# Out:
# 812

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
grade = new_df[["math score", "reading score", "writing score"]].agg("mean", axis = 1)

# %%
def GetGrade(average_mark):
    if average_mark >= 90:
        return 'A'
    elif 80 <= average_mark < 90:
        return 'B'
    elif 70 <= average_mark < 80:
        return 'C'
    elif 60 <= average_mark < 70:
        return 'D'
    elif 50 <= average_mark <60:
        return 'E'
    else:
        return 'F'

new_df['Grade'] = grade.apply(GetGrade)
new_df
# Out:
#      math score  reading score  writing score  gender race/ethnicity  \
# 0            72             72             74  female        group B
# 1            69             90             88  female        group C
# 2            90             95             93  female        group B
# 3            47             57             44    male        group A
# 4            76             78             75    male        group C
# ..          ...            ...            ...     ...            ...
# 995          88             99             95  female        group E
# 996          62             55             55    male        group C
# 997          59             71             65  female        group C
# 998          68             78             77  female        group D
# 999          77             86             86  female        group D
#
#               education         lunch test preparation    group  \
# 0     bachelor's degree      standard             none   group1
# ...
